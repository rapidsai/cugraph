# %%
# !export RAPIDS_NO_INITIALIZE="1"
# !export CUDF_SPILL="1"
# !export LIBCUDF_CUFILE_POLICY="OFF"

from cugraph_bulk_sampling import start_dask_client, benchmark_cugraph_bulk_sampling, load_disk_dataset, construct_graph
from cugraph_bulk_sampling import sample_graph
import os

# %% [markdown]
# # Setup Cluster

# %%
dask_worker_devices='0,1,2,3,4,5,6,7'

# %%
client, cluster = start_dask_client(dask_worker_devices=dask_worker_devices,
                                    jit_unspill=False,
                                    rmm_pool_size=28e9,
                                    rmm_async=True)
# Out:
# Dask client/cluster created using LocalCUDACluster

# %% [markdown]
# # Setup Benchmark

# %%
dataset='ogbn_papers100M'
dataset_root="/datasets/abarghi"
output_root="/tmp/ramdisk"
reverse_edges=True
add_edge_types=False
batch_size=512
seeds_per_call=524288
fanout=[25,25]
replication_factor=2
seed=123

dataset_dir=dataset_root
output_path=output_root
persist=False

# %%
dask_edgelist_df, dask_label_df, node_offsets, edge_offsets, total_num_nodes = \
    load_disk_dataset(
        dataset,
        dataset_dir=dataset_dir,
        reverse_edges=reverse_edges,
        replication_factor=replication_factor,
        persist=False,
        add_edge_types=add_edge_types
    )
num_input_edges = len(dask_edgelist_df)
print(
f"Number of input edges = {num_input_edges:,}"
)

G = construct_graph(
dask_edgelist_df
)
del dask_edgelist_df
print('constructed graph')
# Out:
# Loading edge index for edge type paper__cites__paper
# Loading node labels for node type paper (offset=0)
# Number of input edges = 3,231,371,744
# constructed graph

# %%
input_memory = G.edgelist.edgelist_df.memory_usage().sum().compute()
print(f'input memory: {input_memory}')

output_subdir = os.path.join(output_path, f'{dataset}[{replication_factor}]_b{batch_size}_f{fanout}')
os.makedirs(output_subdir, exist_ok=True)

output_sample_path = os.path.join(output_subdir, 'samples')
os.makedirs(output_sample_path,  exist_ok=True)

batches_per_partition = 200_000 // batch_size
# Out:
# /opt/conda/envs/rapids/lib/python3.10/site-packages/cudf/core/index.py:3139: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# /opt/conda/envs/rapids/lib/python3.10/site-packages/cudf/core/index.py:3139: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# input memory: 51701947904

# %% [markdown]
# # Benchmarking Sample Graph

# %%
# %%timeit -n30 -r1


execution_time, allocation_counts = sample_graph(
    G,
    dask_label_df,
    output_sample_path,
    seed=seed,
    batch_size=batch_size,
    seeds_per_call=seeds_per_call,
    batches_per_partition=batches_per_partition,
    fanout=fanout,
    persist=persist,
)
# Out:
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.5521183013916016
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '269.4MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '116.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '144.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '43.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '38.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '524.5MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '121.5MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.479504346847534
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '927.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '277.2MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '115.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '143.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '47.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '525.4MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '121.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.4864978790283203
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '269.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '110.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '47.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '520.2MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '62.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.5333173274993896
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.7MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '112.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '22.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '40.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '886.8MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '184.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '54.5MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8058741092681885
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '129.8MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '879.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '179.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '62.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9640443325042725
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '557.9MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '207.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '62.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '894.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '183.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '40.8MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.7813918590545654
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '927.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '274.2MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '108.4MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '510.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '58.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '40.4MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.7975833415985107
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.3MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '112.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '510.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '53.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '805.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.688762664794922
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.1MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '49.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '902.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '142.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1011.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '797.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.5299861431121826
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.0MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '129.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '528.8MB',
#                                  'peak_bytes': '2.4GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '22.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '626.3MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.7673709392547607
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '643.9MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '108.0MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '528.5MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '251.1MB',
#                                  'peak_bytes': '2.4GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6301262378692627
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.0MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '44.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '69.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '939.2MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '900.0MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '243.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6305806636810303
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '392.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '39.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '69.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '947.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '896.0MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '251.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.5695598125457764
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '964.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '44.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '938.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '894.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '520.4MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '128.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6411304473876953
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '964.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1017.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '559.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '518.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '524.7MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '121.5MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.659418821334839
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '964.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '55.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '182.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '150.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '179.5MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '62.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6854240894317627
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '44.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '81.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '149.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '111.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '62.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6094613075256348
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '15.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1018.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '81.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '150.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '57.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '54.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.678337574005127
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '33.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '55.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '903.1MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '28.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '38.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '62.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.812675952911377
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '26.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '32.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '903.0MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '48.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9008376598358154
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '33.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '67.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '49.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '529.0MB',
#                                  'peak_bytes': '2.4GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '48.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.62990665435791
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '67.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '151.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '886.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '805.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.6263957023620605
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '67.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '69.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '510.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '899.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '798.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.572017192840576
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1023.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '69.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '142.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '525.2MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '618.6MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.496039390563965
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '938.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '93.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '525.0MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '243.5MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.7569010257720947
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '67.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '886.2MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1018.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '564.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '179.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '128.9MB',
#                                  'peak_bytes': '2.7GB',
# ...
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1009.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '528.9MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '41.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '61.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8833611011505127
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '180.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '69.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '692.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '510.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '896.4MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '805.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 3.109013795852661
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.0MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '597.5MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '100.8MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '179.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '626.3MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9364712238311768
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '33.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '269.5MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '112.8MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '863.4MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '939.2MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '53.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '250.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8597500324249268
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '89.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '49.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '151.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '559.5MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '886.6MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '61.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 3.0190513134002686
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '935.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '27.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1022.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '29.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '81.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '142.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '667.1MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '47.8MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 3.0765509605407715
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '558.3MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '965.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '1009.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '41.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '520.8MB',
#                                  'peak_bytes': '2.4GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '805.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9182934761047363
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '180.8MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '964.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '874.3MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '903.6MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '111.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '612.0MB',
#                                  'peak_bytes': '2.5GB',
#                                  'total_bytes': '36.8GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f9beb8b1a20>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9494895935058594
# allocation_counts:
# {   'tcp://127.0.0.1:35729': {   'current_bytes': '73.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:38199': {   'current_bytes': '644.2MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:38959': {   'current_bytes': '594.4MB',
#                                  'peak_bytes': '2.6GB',
#                                  'total_bytes': '40.1GB'},
#     'tcp://127.0.0.1:40829': {   'current_bytes': '151.8MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:41127': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:43939': {   'current_bytes': '517.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:46319': {   'current_bytes': '1007.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:46357': {   'current_bytes': '250.9MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'}}
# 2.82 s ± 0 ns per loop (mean ± std. dev. of 1 run, 100 loops each)
