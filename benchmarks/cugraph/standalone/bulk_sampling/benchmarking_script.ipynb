# %%
# !export RAPIDS_NO_INITIALIZE="1"
# !export CUDF_SPILL="1"
# !export LIBCUDF_CUFILE_POLICY="OFF"

from cugraph_bulk_sampling import start_dask_client, benchmark_cugraph_bulk_sampling, load_disk_dataset, construct_graph
from cugraph_bulk_sampling import sample_graph
import os

# %% [markdown]
# # Setup Cluster

# %%
dask_worker_devices='0,1,2,3,4,5,6,7'

# %%
client, cluster = start_dask_client(dask_worker_devices=dask_worker_devices,
                                    jit_unspill=False,
                                    rmm_pool_size=28e9,
                                    rmm_async=True)
# Out:
# Dask client/cluster created using LocalCUDACluster

# %% [markdown]
# # Setup Benchmark

# %%
dataset='ogbn_papers100M'
dataset_root="."
output_root="."
reverse_edges=True
add_edge_types=False
batch_size=512
seeds_per_call=524288
fanout=[25,25]
replication_factor=2
seed=123

dataset_dir=dataset_root
output_path=output_root
persist=False

# %%
dask_edgelist_df, dask_label_df, node_offsets, edge_offsets, total_num_nodes = \
    load_disk_dataset(
        dataset,
        dataset_dir=dataset_dir,
        reverse_edges=reverse_edges,
        replication_factor=replication_factor,
        persist=False,
        add_edge_types=add_edge_types
    )
num_input_edges = len(dask_edgelist_df)
print(
f"Number of input edges = {num_input_edges:,}"
)

G = construct_graph(
dask_edgelist_df
)
del dask_edgelist_df
print('constructed graph')
# Out:
# Loading edge index for edge type paper__cites__paper
# Loading node labels for node type paper (offset=0)
# Number of input edges = 3,231,371,744
# constructed graph

# %%
input_memory = G.edgelist.edgelist_df.memory_usage().sum().compute()
print(f'input memory: {input_memory}')

output_subdir = os.path.join(output_path, f'{dataset}[{replication_factor}]_b{batch_size}_f{fanout}')
os.makedirs(output_subdir, exist_ok=True)

output_sample_path = os.path.join(output_subdir, 'samples')
os.makedirs(output_sample_path,  exist_ok=True)

batches_per_partition = 200_000 // batch_size
# Out:
# /opt/conda/envs/rapids/lib/python3.10/site-packages/cudf/core/index.py:3139: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# /opt/conda/envs/rapids/lib/python3.10/site-packages/cudf/core/index.py:3139: FutureWarning: cudf.StringIndex is deprecated and will be removed from cudf in a future version. Use cudf.Index with the appropriate dtype instead.
#   warnings.warn(
# input memory: 51701947904

# %% [markdown]
# # Benchmarking Sample Graph

# %%
# %%timeit -n10 -r1


execution_time, allocation_counts = sample_graph(
    G,
    dask_label_df,
    output_sample_path,
    seed=seed,
    batch_size=batch_size,
    seeds_per_call=seeds_per_call,
    batches_per_partition=batches_per_partition,
    fanout=fanout,
    persist=persist,
)
# Out:
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 3.9013142585754395
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '935.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '791.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '992.4MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8573741912841797
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '932.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1020.3MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '837.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '992.0MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9200961589813232
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '939.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '952.7MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '777.7MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '984.2MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8338382244110107
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '932.5MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '783.8MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '984.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.1GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.8734583854675293
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '932.0MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '783.6MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '983.9MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.9434382915496826
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '940.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '953.1MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '773.6MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '968.7MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.874237298965454
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '932.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.7GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '774.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.9GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '983.8MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 3.0073914527893066
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '931.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '957.6MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '788.4MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '984.5MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.918217658996582
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '932.4MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '953.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '784.0MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '984.5MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# created batches
# flushed all batches
# function:  sample_graph
# function args: (<cugraph.structure.graph_classes.MultiGraph object at 0x7f462c72b250>, <dask_cudf.DataFrame | 16 tasks | 8 npartitions>, '/tmp/ramdisk/ogbn_papers100M[2]_b512_f[25, 25]/samples') kwargs: {'seed': 123, 'batch_size': 512, 'seeds_per_call': 524288, 'batches_per_partition': 390, 'fanout': [25, 25], 'persist': False}
# execution_time: 2.746492624282837
# allocation_counts:
# {   'tcp://127.0.0.1:33605': {   'current_bytes': '931.9MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.6GB'},
#     'tcp://127.0.0.1:35747': {   'current_bytes': '954.2MB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '39.9GB'},
#     'tcp://127.0.0.1:36299': {   'current_bytes': '1.1GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.4GB'},
#     'tcp://127.0.0.1:37997': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'},
#     'tcp://127.0.0.1:41267': {   'current_bytes': '787.1MB',
#                                  'peak_bytes': '2.7GB',
#                                  'total_bytes': '36.8GB'},
#     'tcp://127.0.0.1:42205': {   'current_bytes': '984.3MB',
#                                  'peak_bytes': '2.8GB',
#                                  'total_bytes': '40.0GB'},
#     'tcp://127.0.0.1:44103': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.3GB'},
#     'tcp://127.0.0.1:46793': {   'current_bytes': '1.0GB',
#                                  'peak_bytes': '2.9GB',
#                                  'total_bytes': '40.2GB'}}
# 3.01 s ± 0 ns per loop (mean ± std. dev. of 1 run, 10 loops each)
